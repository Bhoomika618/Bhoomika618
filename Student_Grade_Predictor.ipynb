# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhoomika618/Bhoomika618/blob/main/Student_Grade_Predictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🎓 Student Academic Performance Analysis 📊

# %% [markdown]
# ---
#
# ## 📌 Table of Contents
# 1. [Introduction](#introduction)
#    - [Why analyze student performance?](#importance)
# 2. [Loading Libraries & Data](#loading)
# 3. [Quick Look at the Data](#data)
#    - [Dataset Overview](#overview)
#    - [Attribute Information](#attributes)
# 4. [Visualize Missing Values](#missing)
# 5. [Data Preparation](#preparation)
#    - [Creating New Columns](#newcolumns)
#    - [Grading System](#grading)
# 6. [Exploratory Data Analysis (EDA)](#eda)
# 7. [Model Training & Prediction](#model)
# 8. [Results & Evaluation](#results)
# 9. [Conclusion](#conclusion)
# 10. [Future Scope](#scope)
#
# ---
#
# ## 1. Introduction <a id="introduction"></a>
# This dataset contains exam scores and demographic information of students.
# The aim of this project is to:
# - Analyze factors affecting student performance.
# - Build a Machine Learning model to predict academic success.
#
# ---
#
# ### Why analyze student performance? <a id="importance"></a>
# - Early detection of at-risk students.
# - Helps teachers & institutions improve teaching methods.
# - Provides personalized recommendations.
#
# ---
